# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
df= pd.read_csv("../../data/processed/combined.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 631 entries, 0 to 630
# Data columns (total 18 columns):
# Unnamed: 0              631 non-null int64
# year                    631 non-null int64
# playername              631 non-null object
# team                    631 non-null object
# age                     631 non-null int64
# g                       631 non-null int64
# gs                      631 non-null int64
# attempts                631 non-null int64
# yards                   631 non-null int64
# tds                     631 non-null int64
# longgain                631 non-null int64
# yardsperatt             631 non-null float64
# yardspergame            631 non-null float64
# fumbles                 631 non-null int64
# basesalarycap (10^8)    631 non-null float64
# Percenthit (%)          631 non-null float64
# caphit (M)              631 non-null float64
# cashspent (M)           631 non-null float64
# dtypes: float64(6), int64(10), object(2)
# ...

# %%
df.head()
# Out:
#    Unnamed: 0  year       playername team  age   g  gs  attempts  yards  tds  \
# 0         987  2020      Aaron Jones  GNB   26   5   5        75    389    5
# 1         988  2019      Aaron Jones  GNB   25  16  16       236   1084   16
# 2         989  2018      Aaron Jones  GNB   24  12   8       133    728    8
# 3         990  2017      Aaron Jones  GNB   23  12   4        81    448    4
# 4        1384  2020  Adrian Peterson  DET   35   6   4        80    314    2
#
#    longgain  yardsperatt  yardspergame  fumbles  basesalarycap (10^8)  \
# 0        75          5.2          77.8        1                 1.982
# 1        56          4.6          67.8        3                 1.882
# 2        67          5.5          60.7        1                 1.772
# 3        46          5.5          37.3        0                 1.670
# 4        27          3.9          52.3        0                 1.982
#
#    Percenthit (%)  caphit (M)  cashspent (M)
# ...

# %%
df = df.drop('year',axis=1)
df = df.drop('playername',axis=1)
df = df.drop('team',axis=1)
df = df.drop('basesalarycap (10^8)',axis=1)
df = df.drop('cashspent (M)',axis=1)

# %%
df.head()
# Out:
#    Unnamed: 0  age   g  gs  attempts  yards  tds  longgain  yardsperatt  \
# 0         987   26   5   5        75    389    5        75          5.2
# 1         988   25  16  16       236   1084   16        56          4.6
# 2         989   24  12   8       133    728    8        67          5.5
# 3         990   23  12   4        81    448    4        46          5.5
# 4        1384   35   6   4        80    314    2        27          3.9
#
#    yardspergame  fumbles  Percenthit (%)  caphit (M)
# 0          77.8        1        1.100909    2.182002
# 1          67.8        3        0.369547    0.695487
# 2          60.7        1        0.293098    0.519369
# 3          37.3        0        0.308675    0.515487
# 4          52.3        0        0.529768    1.050000

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'age', 'g', 'gs', 'attempts', 'yards', 'tds', 'longgain',
#        'yardsperatt', 'yardspergame', 'fumbles', 'Percenthit (%)',
#        'caphit (M)'],
#       dtype='object')

# %%
df = df.drop('caphit (M)',axis=1)

# %%
df.head()
# Out:
#    Unnamed: 0  age   g  gs  attempts  yards  tds  longgain  yardsperatt  \
# 0         987   26   5   5        75    389    5        75          5.2
# 1         988   25  16  16       236   1084   16        56          4.6
# 2         989   24  12   8       133    728    8        67          5.5
# 3         990   23  12   4        81    448    4        46          5.5
# 4        1384   35   6   4        80    314    2        27          3.9
#
#    yardspergame  fumbles  Percenthit (%)
# 0          77.8        1        1.100909
# 1          67.8        3        0.369547
# 2          60.7        1        0.293098
# 3          37.3        0        0.308675
# 4          52.3        0        0.529768

# %%
df.head()
# Out:
#    Unnamed: 0  age   g  gs  attempts  yards  tds  longgain  yardsperatt  \
# 0         987   26   5   5        75    389    5        75          5.2
# 1         988   25  16  16       236   1084   16        56          4.6
# 2         989   24  12   8       133    728    8        67          5.5
# 3         990   23  12   4        81    448    4        46          5.5
# 4        1384   35   6   4        80    314    2        27          3.9
#
#    yardspergame  fumbles  Percenthit (%)
# 0          77.8        1        1.100909
# 1          67.8        3        0.369547
# 2          60.7        1        0.293098
# 3          37.3        0        0.308675
# 4          52.3        0        0.529768

# %%
df.head()
# Out:
#    Unnamed: 0  age   g  gs  attempts  yards  tds  longgain  yardsperatt  \
# 0         987   26   5   5        75    389    5        75          5.2
# 1         988   25  16  16       236   1084   16        56          4.6
# 2         989   24  12   8       133    728    8        67          5.5
# 3         990   23  12   4        81    448    4        46          5.5
# 4        1384   35   6   4        80    314    2        27          3.9
#
#    yardspergame  fumbles  Percenthit (%)
# 0          77.8        1        1.100909
# 1          67.8        3        0.369547
# 2          60.7        1        0.293098
# 3          37.3        0        0.308675
# 4          52.3        0        0.529768

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'age', 'g', 'gs', 'attempts', 'yards', 'tds', 'longgain',
#        'yardsperatt', 'yardspergame', 'fumbles', 'Percenthit (%)'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 631 entries, 0 to 630
# Data columns (total 12 columns):
# Unnamed: 0        631 non-null int64
# age               631 non-null int64
# g                 631 non-null int64
# gs                631 non-null int64
# attempts          631 non-null int64
# yards             631 non-null int64
# tds               631 non-null int64
# longgain          631 non-null int64
# yardsperatt       631 non-null float64
# yardspergame      631 non-null float64
# fumbles           631 non-null int64
# Percenthit (%)    631 non-null float64
# dtypes: float64(3), int64(9)
# memory usage: 59.3 KB

# %%
df = df.drop('Unnamed: 0',axis=1)

# %%
df.head()
# Out:
#    age   g  gs  attempts  yards  tds  longgain  yardsperatt  yardspergame  \
# 0   26   5   5        75    389    5        75          5.2          77.8
# 1   25  16  16       236   1084   16        56          4.6          67.8
# 2   24  12   8       133    728    8        67          5.5          60.7
# 3   23  12   4        81    448    4        46          5.5          37.3
# 4   35   6   4        80    314    2        27          3.9          52.3
#
#    fumbles  Percenthit (%)
# 0        1        1.100909
# 1        3        0.369547
# 2        1        0.293098
# 3        0        0.308675
# 4        0        0.529768

# %%
sns.distplot(df['Percenthit (%)'],bins=30,kde=True,color='blue')

# %%
sns.heatmap(df.corr(),cmap='coolwarm')
plt.title('df.corr()')
# Out:
# Text(0.5, 1, 'df.corr()')

# %%
plt.figure(figsize=(6,6))
df_corr = df.corr()
sns.heatmap(df_corr[['Percenthit (%)']].sort_values(by=['Percenthit (%)'],ascending=False),vmin=-1,cmap='coolwarm',annot=True);

# %% [markdown]
# Now for the Modelling

# %%
from sklearn.model_selection import train_test_split

# %%
X = df.drop('Percenthit (%)',axis=1).values
y = df['Percenthit (%)'].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_test = scaler.fit_transform(X_test)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
X_train.shape
# Out:
# (441, 10)

# %%
model = Sequential()

model.add(Dense(10, activation="relu"))
model.add(Dense(10, activation="relu"))
model.add(Dense(10, activation="relu"))
model.add(Dense(10, activation="relu"))

model.add(Dense(1))

model.compile(optimizer="adam", loss="mse")

# %%
model.fit(x=X_train, y= y_train, validation_data=(X_test,y_test),batch_size=32,epochs=500)
# Out:
# Epoch 1/500
# 14/14 [==============================] - 0s 5ms/step - loss: 4.9744 - val_loss: 5.3128
# Epoch 2/500
# 14/14 [==============================] - 0s 2ms/step - loss: 4.5034 - val_loss: 4.7826
# Epoch 3/500
# 14/14 [==============================] - 0s 3ms/step - loss: 3.9804 - val_loss: 4.2241
# Epoch 4/500
# 14/14 [==============================] - 0s 3ms/step - loss: 3.4627 - val_loss: 3.7543
# Epoch 5/500
# 14/14 [==============================] - 0s 3ms/step - loss: 3.1099 - val_loss: 3.4999
# Epoch 6/500
# 14/14 [==============================] - 0s 3ms/step - loss: 2.9743 - val_loss: 3.4384
# Epoch 7/500
# 14/14 [==============================] - 0s 3ms/step - loss: 2.9729 - val_loss: 3.4307
# Epoch 8/500
# 14/14 [==============================] - 0s 3ms/step - loss: 2.9458 - val_loss: 3.4097
# Epoch 9/500
# 14/14 [==============================] - 0s 3ms/step - loss: 2.9427 - val_loss: 3.3973
# Epoch 10/500
# ...

# %%
model.history.history
# Out:
# {'loss': [4.974440574645996,
#   4.503417491912842,
#   3.9803850650787354,
#   3.462656259536743,
#   3.109907627105713,
#   2.9743270874023438,
#   2.972949743270874,
#   2.9457669258117676,
#   2.9426891803741455,
#   2.924034833908081,
#   2.9151337146759033,
#   2.903088331222534,
#   2.893524408340454,
#   2.8779239654541016,
#   2.862563133239746,
#   2.850039005279541,
#   2.8383431434631348,
#   2.8285071849823,
#   2.8120875358581543,
#   2.792741298675537,
#   2.7772367000579834,
#   2.7598330974578857,
#   2.753918170928955,
#   2.726681709289551,
#   2.717243194580078,
#   2.6972994804382324,
#   2.6771724224090576,
#   2.6720359325408936,
#   2.653972625732422,
#   2.659949541091919,
#   2.6525063514709473,
#   2.626213788986206,
#   2.6151156425476074,
#   2.611086368560791,
#   2.6104323863983154,
#   2.5900375843048096,
#   2.590557813644409,
#   2.577714681625366,
#   2.569408416748047,
#   2.5674612522125244,
#   2.5596232414245605,
#   2.557483434677124,
# ...

# %%
losses = pd.DataFrame(model.history.history)

# %%
losses.plot()

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, explained_variance_score

# %%
predictions = model.predict(X_test)

# %%
predictions
# Out:
# array([[ 1.3079548 ],
#        [ 1.1363332 ],
#        [ 5.445678  ],
#        [ 0.7783489 ],
#        [ 1.0827075 ],
#        [ 4.4192986 ],
#        [ 3.0879405 ],
#        [ 1.7207795 ],
#        [ 1.4950268 ],
#        [ 0.77541655],
#        [ 1.6989143 ],
#        [ 1.2509059 ],
#        [ 1.5963341 ],
#        [ 2.0286117 ],
#        [ 5.3626113 ],
#        [ 1.5187234 ],
#        [ 1.2903783 ],
#        [ 0.63205075],
#        [ 1.9063879 ],
#        [ 1.6266977 ],
#        [ 0.40589368],
#        [ 1.4555    ],
#        [ 3.5986333 ],
#        [ 1.088828  ],
#        [ 3.0030456 ],
#        [ 0.5728005 ],
#        [ 0.24763079],
#        [ 0.94150865],
#        [ 0.98822   ],
#        [ 1.9455693 ],
#        [ 0.59022343],
#        [ 2.3723738 ],
#        [ 5.586598  ],
#        [ 0.7701181 ],
#        [ 0.5373923 ],
#        [ 3.5850017 ],
#        [ 0.7587328 ],
#        [ 0.8178352 ],
#        [ 0.50939107],
#        [ 1.2600971 ],
#        [ 3.9683123 ],
# ...

# %%
mean_squared_error(y_test,predictions)
# Out:
# 2.3520777446241388

# %%
import numpy as np
np.sqrt(mean_squared_error(y_test,predictions))
# Out:
# 1.533648507521896

# %%
mean_absolute_error(y_test,predictions)
# Out:
# 1.059032491405343

# %%
df["Percenthit (%)"].describe()
# Out:
# count    631.000000
# mean       1.632765
# std        1.940671
# min        0.000000
# 25%        0.407109
# 50%        0.717603
# 75%        2.207487
# max       11.300813
# Name: Percenthit (%), dtype: float64

# %%
explained_variance_score(y_test,predictions)
# Out:
# 0.4522765281828418

# %%
plt.figure(figsize=(6,6))
plt.scatter(y_test,predictions)
plt.plot(y_test,y_test,'r')

# %%
df
# Out:
#      age   g  gs  attempts  yards  tds  longgain  yardsperatt  yardspergame  \
# 0     26   5   5        75    389    5        75          5.2          77.8
# 1     25  16  16       236   1084   16        56          4.6          67.8
# 2     24  12   8       133    728    8        67          5.5          60.7
# 3     23  12   4        81    448    4        46          5.5          37.3
# 4     35   6   4        80    314    2        27          3.9          52.3
# ..   ...  ..  ..       ...    ...  ...       ...          ...           ...
# 626   22  13   3        77    312    1        19          4.1          24.0
# 627   32  12   6       138    377    2        16          2.7          31.4
# 628   24   8   0        31     89    1        18          2.9          11.1
# 629   23  13   5        76    293    1        16          3.9          22.5
# 630   22  14  12       250    973    7        40          3.9          69.5
#
#      fumbles  Percenthit (%)
# ...

# %%
single_rb = df.drop('Percenthit (%)', axis=1).iloc[0]

# %%
single_rb.values
# Out:
# array([ 26. ,   5. ,   5. ,  75. , 389. ,   5. ,  75. ,   5.2,  77.8,
#          1. ])

# %%
scaler.transform(single_rb.values.reshape(-1,10))
# Out:
# array([[0.35714286, 0.26666667, 0.3125    , 0.18717949, 0.18666667,
#         0.27777778, 0.80681818, 0.63953488, 0.59405941, 0.125     ]])

# %%
scaled_rb = scaler.transform(single_rb.values.reshape(-1,10))

# %%
model.predict(scaled_rb)
# Out:
# array([[4.958992]], dtype=float32)

# %%
df.head()
# Out:
#    age   g  gs  attempts  yards  tds  longgain  yardsperatt  yardspergame  \
# 0   26   5   5        75    389    5        75          5.2          77.8
# 1   25  16  16       236   1084   16        56          4.6          67.8
# 2   24  12   8       133    728    8        67          5.5          60.7
# 3   23  12   4        81    448    4        46          5.5          37.3
# 4   35   6   4        80    314    2        27          3.9          52.3
#
#    fumbles  Percenthit (%)
# 0        1        1.100909
# 1        3        0.369547
# 2        1        0.293098
# 3        0        0.308675
# 4        0        0.529768

# %%
#predicts 4% when in reality got paid 1%
#yikes
