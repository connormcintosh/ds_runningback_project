# %%
import pandas as pd

frames = []

# %%
for i in range(1997, 2021):
    df = pd.read_csv(f"../../data/raw/offensive stats/passing{i}.csv")
    df["Year"] = i
    frames.append(df)

# %%
output = pd.concat(frames)

# %%
output.assign(
    Team = lambda dataframe: dataframe['Team'].map(lambda team: team if team != "Football Team" else "Redskins") 
).reset_index()
# Out:
#      index      Team  Att  Cmp  Cmp %  Yds/Att  Pass Yds  TD   INT   Rate  \
# 0        0     49ers  432  278   64.4      7.9      3432  20  11.0   93.6
# 1        1     Bears  595  336   56.5      5.9      3501  14  22.0   66.1
# 2        2   Bengals  504  302   59.9      7.1      3603  21   9.0   88.3
# 3        3     Bills  546  293   53.7      5.9      3213  14  25.0   60.8
# 4        4   Broncos  513  287   55.9      7.2      3704  27  11.0   87.4
# ..     ...       ...  ...  ...    ...      ...       ...  ..   ...    ...
# 743     27  Seahawks  563  388   68.9      7.5      4245  40  13.0  105.0
# 744     28  Steelers  656  428   65.2      6.3      4129  35  11.0   93.5
# 745     29    Texans  546  383   70.1      8.9      4843  33   7.0  112.3
# 746     30    Titans  485  316   65.2      7.9      3826  33   7.0  105.9
# 747     31   Vikings  516  349   67.6      8.3      4265  35  13.0  105.0
#
#        1st  1st%  20+ 40+  Lng  Sck   SckY  Year
# ...

# %%
for col in output.columns[2:]:
    output[col] = output[col].map(lambda c: c.replace("T", "") if isinstance(c, str) else c ) # remove touchdown indicator

# %%
output.columns
# Out:
# Index(['Team', 'Att', 'Cmp', 'Cmp %', 'Yds/Att', 'Pass Yds', 'TD', 'INT',
#        'Rate', '1st', '1st%', '20+', '40+', 'Lng', 'Sck', 'SckY', 'Year'],
#       dtype='object')

# %%
output.tail()
# Out:
#         Team  Att  Cmp  Cmp %  Yds/Att  Pass Yds  TD   INT   Rate    1st  \
# 27  Seahawks  563  388   68.9      7.5      4245  40  13.0  105.0  216.0
# 28  Steelers  656  428   65.2      6.3      4129  35  11.0   93.5  206.0
# 29    Texans  546  383   70.1      8.9      4843  33   7.0  112.3  222.0
# 30    Titans  485  316   65.2      7.9      3826  33   7.0  105.9  203.0
# 31   Vikings  516  349   67.6      8.3      4265  35  13.0  105.0  212.0
#
#     1st%  20+ 40+ Lng  Sck   SckY  Year
# 27  38.4   45  11  62   48  304.0  2020
# 28  31.4   48   7  84   14  126.0  2020
# 29  40.7   70  11  77   50  305.0  2020
# 30  41.9   44  13  75   25  173.0  2020
# 31  41.1   58   7  71   39  256.0  2020

# %%
for col in output.columns[2:]:
    print(col)
    output[col] = pd.to_numeric(output[col])
# Out:
# Cmp
# Cmp %
# Yds/Att
# Pass Yds
# TD
# INT
# Rate
# 1st
# 1st%
# 20+
# 40+
# Lng
# Sck
# SckY
# Year

# %%
output.to_csv("../../data/raw/offensive stats/passing.csv")
